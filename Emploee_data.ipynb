# %%
import os
#os.getcwd()#current working directory

# %%
# Change the current working directory 
#output result will saved in the cwd
#os.chdir('C://Users//shuail') *
#os.chdir('C:/Shuai/workshop/Python for Data Analytics')

# %%
os.getcwd()
# Out:
# '/home/jovyan'

# %% [markdown]
# ![3n8tRry6fYg7sNyhFDPQwR-320-80.jpg](attachment:3n8tRry6fYg7sNyhFDPQwR-320-80.jpg)

# %% [markdown]
# introduce pandas: https://pandas.pydata.org/

# %%
#pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("Employee data.csv")
df
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 0             0    1.0    Male  1.165415e+10    15   Manager  57000.0
# 1             1    2.0    Male  1.185296e+10    16  Clerical  40200.0
# 2             2    3.0  Female  1.094334e+10    12  Clerical  21450.0
# 3             3    4.0  Female  1.150252e+10     8  Clerical  21900.0
# 4             4    5.0    Male  1.174936e+10    15  Clerical  45000.0
# ..          ...    ...     ...           ...   ...       ...      ...
# 469         469  470.0    Male  1.203180e+10    12  Clerical  26250.0
# 470         470  471.0    Male  1.211164e+10    15  Clerical  26400.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
# 472         472  473.0  Female  1.120634e+10    12  Clerical  21450.0
# 473         473  474.0  Female  1.218292e+10    12  Clerical  29400.0
#
#      salbegin  jobtime prevexp minority
# 0     27000.0     98.0   144.0       No
# 1     18750.0     98.0    36.0       No
# 2     12000.0     98.0   381.0       No
# 3     13200.0     98.0   190.0       No
# 4     21000.0     98.0   138.0       No
# ..        ...      ...     ...      ...
# 469   15750.0     64.0    69.0      Yes
# 470   15750.0     64.0    32.0      Yes
# 471   15750.0     63.0    46.0       No
# 472   12750.0     63.0   139.0       No
# 473   14250.0     63.0     9.0       No
#
# [474 rows x 11 columns]

# %%
#df.head()#Select first 5 rows
df.tail()
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 469         469  470.0    Male  1.203180e+10    12  Clerical  26250.0
# 470         470  471.0    Male  1.211164e+10    15  Clerical  26400.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
# 472         472  473.0  Female  1.120634e+10    12  Clerical  21450.0
# 473         473  474.0  Female  1.218292e+10    12  Clerical  29400.0
#
#      salbegin  jobtime prevexp minority
# 469   15750.0     64.0    69.0      Yes
# 470   15750.0     64.0    32.0      Yes
# 471   15750.0     63.0    46.0       No
# 472   12750.0     63.0   139.0       No
# 473   14250.0     63.0     9.0       No

# %%
df.shape
# Out:
# (474, 11)

# %% [markdown]
# **1. read other type of files?**

# %% [markdown]
# **2.data type?** *

# %% [markdown]
# 1. object
# * text
# * numerica + non-numeric
#
# 2. numeric
#
# * integer
# * float

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# id            float64
# gender         object
# bdate         float64
# educ            int64
# jobcat         object
# salary        float64
# salbegin      float64
# jobtime       float64
# prevexp        object
# minority       object
# dtype: object

# %%
df['salary'].describe()
# Out:
# count       474.000000
# mean      34419.567511
# std       17075.661465
# min       15750.000000
# 25%       24000.000000
# 50%       28875.000000
# 75%       36937.500000
# max      135000.000000
# Name: salary, dtype: float64

# %%
df['gender'].describe()
# Out:
# count      474
# unique       2
# top       Male
# freq       258
# Name: gender, dtype: object

# %%
df['prevexp'].describe()
# Out:
# count         474
# unique        208
# top       missing
# freq           24
# Name: prevexp, dtype: object

# %%
df[df['prevexp']=='missing']
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 7             7    8.0  Female  1.210395e+10    12  Clerical  21900.0
# 72           72   73.0  Female  1.215959e+10    12  Clerical  26400.0
# 74           74   75.0  Female  1.208088e+10    15  Clerical  24150.0
# 82           82   83.0  Female  1.214922e+10    12  Clerical  22950.0
# 89           89   90.0  Female  1.121446e+10     8  Clerical  16200.0
# 92           92   93.0  Female  1.216175e+10    12  Clerical  25950.0
# 123         123  124.0  Female  1.201124e+10    16  Clerical  38550.0
# 134         134  135.0  Female  1.216849e+10    12  Clerical  26250.0
# 223         223  224.0  Female  1.111121e+10    12  Clerical  16200.0
# 224         224  225.0  Female  1.214931e+10    15  Clerical  21900.0
# 236         236  237.0  Female  1.220115e+10    12  Clerical  22650.0
# 242         242  243.0  Female  1.219130e+10    12  Clerical  23100.0
# 245         245  246.0  Female  1.215734e+10    12  Clerical  24900.0
# 252         252  253.0  Female  1.134017e+10     8  Clerical  17100.0
# 264         264  265.0  Female  1.221083e+10    12  Clerical  23400.0
# 266         266  267.0  Female  1.220815e+10    12  Clerical  18150.0
# 312         312  313.0  Female  1.221350e+10    12  Clerical  21300.0
# 391         391  392.0  Female  1.223070e+10    12  Clerical  21600.0
# 392         392  393.0  Female  1.220288e+10    12  Clerical  27900.0
# 395         395  396.0  Female  1.223908e+10    12  Clerical  20850.0
# 398         398  399.0  Female  1.222249e+10    12  Clerical  20400.0
# 400         400  401.0  Female  1.222560e+10    12  Clerical  22800.0
# 438         438  439.0  Female  1.223450e+10    12  Clerical  20400.0
# 458         458  459.0  Female  1.225437e+10    12  Clerical  21750.0
#
#      salbegin  jobtime  prevexp minority
# 7      9750.0     98.0  missing       No
# 72    10500.0     93.0  missing       No
# 74    11550.0     93.0  missing       No
# 82    11250.0     93.0  missing      Yes
# 89     9750.0     92.0  missing       No
# 92    10950.0     92.0  missing       No
# 123   16500.0     90.0  missing       No
# 134   10950.0     89.0  missing       No
# 223   10200.0     82.0  missing       No
# 224   12750.0     82.0  missing       No
# 236   11250.0     81.0  missing       No
# 242   10950.0     81.0  missing       No
# 245   11250.0     81.0  missing       No
# 252   10200.0     81.0  missing      Yes
# 264   11250.0     80.0  missing       No
# 266   10950.0     80.0  missing       No
# 312   11250.0     77.0  missing       No
# 391   12000.0     69.0  missing       No
# 392   12450.0     69.0  missing       No
# 395   11250.0     69.0  missing       No
# 398   11250.0     69.0  missing       No
# 400   11250.0     69.0  missing       No
# 438   11250.0     66.0  missing       No
# 458   11250.0     65.0  missing       No

# %% [markdown]
# 1. remove missing
# 2. impute
# 3. predict the missing

# %% [markdown]
# ## 1. anaylsis gender

# %%
df['gender'].describe()
# Out:
# count      474
# unique       2
# top       Male
# freq       258
# Name: gender, dtype: object

# %%
df['gender'].unique() #*
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['educ'].unique()
# Out:
# array([15, 16, 12,  8, 19, 17, 18, 14, 20, 21])

# %%
# fliter. how many datapoints that gender==male 
male=df[df['gender']=='Male']
male.shape
# Out:
# (258, 11)

# %%
female=df[df['gender']=='Female']
female.shape
# Out:
# (216, 11)

# %% [markdown]
# **more filters?**

# %%
df[(df['gender']=='Female')&(df['jobcat']=='Manager')]
# Out:
#      Unnamed: 0     id  gender         bdate  educ   jobcat   salary  \
# 119         119  120.0  Female  1.205729e+10    16  Manager  37800.0
# 133         133  134.0  Female  1.133127e+10    16  Manager  41550.0
# 167         167  168.0  Female  1.197660e+10    16  Manager  46875.0
# 239         239  240.0  Female  1.194964e+10    16  Manager  54375.0
# 276         276  277.0  Female  1.207362e+10    16  Manager  43000.0
# 347         347  348.0  Female  1.198083e+10    16  Manager  56750.0
# 370         370  371.0  Female  1.210127e+10    16  Manager  58125.0
# 412         412  413.0  Female  1.209928e+10    16  Manager  43500.0
# 461         461  462.0  Female  1.202351e+10    16  Manager  34410.0
# 467         467  468.0  Female  1.209021e+10    16  Manager  55750.0
#
#      salbegin  jobtime prevexp minority
# 119   15750.0     90.0     7.0       No
# 133   24990.0     89.0   285.0       No
# 167   17250.0     86.0    19.0       No
# 239   18750.0     81.0    81.0       No
# 276   17490.0     79.0    20.0       No
# 347   30000.0     73.0    15.0       No
# 370   18000.0     71.0    11.0       No
# 412   19500.0     68.0    11.0       No
# 461   19500.0     65.0    79.0       No
# 467   19980.0     64.0    36.0       No

# %%
df[(df['gender']=='Female')&(df['jobcat']=='Manager') & (df['educ']>15)]
# Out:
#      Unnamed: 0     id  gender         bdate  educ   jobcat   salary  \
# 119         119  120.0  Female  1.205729e+10    16  Manager  37800.0
# 133         133  134.0  Female  1.133127e+10    16  Manager  41550.0
# 167         167  168.0  Female  1.197660e+10    16  Manager  46875.0
# 239         239  240.0  Female  1.194964e+10    16  Manager  54375.0
# 276         276  277.0  Female  1.207362e+10    16  Manager  43000.0
# 347         347  348.0  Female  1.198083e+10    16  Manager  56750.0
# 370         370  371.0  Female  1.210127e+10    16  Manager  58125.0
# 412         412  413.0  Female  1.209928e+10    16  Manager  43500.0
# 461         461  462.0  Female  1.202351e+10    16  Manager  34410.0
# 467         467  468.0  Female  1.209021e+10    16  Manager  55750.0
#
#      salbegin  jobtime prevexp minority
# 119   15750.0     90.0     7.0       No
# 133   24990.0     89.0   285.0       No
# 167   17250.0     86.0    19.0       No
# 239   18750.0     81.0    81.0       No
# 276   17490.0     79.0    20.0       No
# 347   30000.0     73.0    15.0       No
# 370   18000.0     71.0    11.0       No
# 412   19500.0     68.0    11.0       No
# 461   19500.0     65.0    79.0       No
# 467   19980.0     64.0    36.0       No

# %%
df[(df['educ']==8)| (df['educ']==17)]
# Out:
#      Unnamed: 0     id  gender         bdate  educ     jobcat   salary  \
# 3             3    4.0  Female  1.150252e+10     8   Clerical  21900.0
# 11           11   12.0    Male  1.209401e+10     8   Clerical  28350.0
# 34           34   35.0    Male  1.195551e+10    17    Manager  81250.0
# 35           35   36.0  Female  1.201729e+10     8   Clerical  31350.0
# 43           43   44.0    Male  1.201271e+10     8   Clerical  29250.0
# ..          ...    ...     ...           ...   ...        ...      ...
# 428         428  429.0    Male  1.148135e+10     8  Custodial  30000.0
# 436         436  437.0    Male  1.107302e+10     8   Clerical  26250.0
# 439         439  440.0  Female  1.152058e+10     8   Clerical  24150.0
# 442         442  443.0  Female  1.092900e+10     8   Clerical  21600.0
# 460         460  461.0  Female  1.139417e+10     8   Clerical  21600.0
#
#      salbegin  jobtime prevexp minority
# 3     13200.0     98.0   190.0       No
# 11    12000.0     98.0    26.0      Yes
# 34    30000.0     96.0    18.0       No
# 35    11250.0     96.0    52.0       No
# 43    14250.0     95.0    50.0       No
# ..        ...      ...     ...      ...
# 428   15750.0     67.0   305.0      Yes
# 436   16050.0     66.0   264.0       No
# 439   12750.0     66.0    96.0       No
# 442   13500.0     66.0   228.0       No
# 460   13500.0     65.0   173.0       No
#
# [64 rows x 11 columns]

# %%
#combine 2 dataframe
pd.concat([female,male]).sort_index()
# more detail in cheat_sheet
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 0             0    1.0    Male  1.165415e+10    15   Manager  57000.0
# 1             1    2.0    Male  1.185296e+10    16  Clerical  40200.0
# 2             2    3.0  Female  1.094334e+10    12  Clerical  21450.0
# 3             3    4.0  Female  1.150252e+10     8  Clerical  21900.0
# 4             4    5.0    Male  1.174936e+10    15  Clerical  45000.0
# ..          ...    ...     ...           ...   ...       ...      ...
# 469         469  470.0    Male  1.203180e+10    12  Clerical  26250.0
# 470         470  471.0    Male  1.211164e+10    15  Clerical  26400.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
# 472         472  473.0  Female  1.120634e+10    12  Clerical  21450.0
# 473         473  474.0  Female  1.218292e+10    12  Clerical  29400.0
#
#      salbegin  jobtime prevexp minority
# 0     27000.0     98.0   144.0       No
# 1     18750.0     98.0    36.0       No
# 2     12000.0     98.0   381.0       No
# 3     13200.0     98.0   190.0       No
# 4     21000.0     98.0   138.0       No
# ..        ...      ...     ...      ...
# 469   15750.0     64.0    69.0      Yes
# 470   15750.0     64.0    32.0      Yes
# 471   15750.0     63.0    46.0       No
# 472   12750.0     63.0   139.0       No
# 473   14250.0     63.0     9.0       No
#
# [474 rows x 11 columns]

# %%
#save dataframe to csv
female.to_csv('female.csv')

# %% [markdown]
# **save dataframe to other datatype?**

# %% [markdown]
# ## 2. salary analysis

# %%
df['salary'].describe()
# Out:
# count       474.000000
# mean      34419.567511
# std       17075.661465
# min       15750.000000
# 25%       24000.000000
# 50%       28875.000000
# 75%       36937.500000
# max      135000.000000
# Name: salary, dtype: float64

# %% [markdown]
# **What is Quartiles?**

# %%
#pip install matplotlib

# %%
#pip install plotly

# %%
import matplotlib.pyplot as plt
import plotly.express as px
plt.figure(figsize=(6, 4))
fig = px.box(df, y='salary')
fig.show()
# Out:
# <div>                            <div id="961ab8bf-d631-411d-b147-9364e9793608" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("961ab8bf-d631-411d-b147-9364e9793608")) {                    Plotly.newPlot(                        "961ab8bf-d631-411d-b147-9364e9793608",                        [{"alignmentgroup":"True","hovertemplate":"salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":
0,62500.0,27300.0,24450.0,33000.0,37050.0,24450.0,31950.0,47250.0,26100.0,15900.0,23700.0,21750.0,59400.0,24450.0,103500.0,35700.0,22200.0,22950.0,23100.0,56750.0,29100.0,37650.0,27900.0,21150.0,31200.0,20550.0,25950.0,28350.0,17700.0,23550.0,19950.0,29400.0,28800.0,16950.0,35700.0,17400.0,21450.0,24750.0,16950.0,26100.0,28050.0,36600.0,58125.0,21300.0,22500.0,29400.0,27450.0,29850.0,25350.0,15750.0,19650.0,21000.0,27000.0,24000.0,78500.0,20850.0,30000.0,28500.0,65000.0,30150.0,66875.0,24150.0,24450.0,21600.0,27900.0,29100.0,22650.0,20850.0,22950.0,30600.0,20400.0,23850.0,22800.0,20700.0,21300.0,24300.0,19650.0,600 ...

# %% [markdown]
# **add a filter to get a dataframe that salary is higher than mean value**

# %% [markdown]
# take a few seconds to think about how to write the code.

# %%
#coding below:

# %%
# one filter that salary above mean
df[df['salary']>34419.567511]
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 0             0    1.0    Male  1.165415e+10    15   Manager  57000.0
# 1             1    2.0    Male  1.185296e+10    16  Clerical  40200.0
# 4             4    5.0    Male  1.174936e+10    15  Clerical  45000.0
# 6             6    7.0    Male  1.178755e+10    15  Clerical  36000.0
# 13           13   14.0  Female  1.156153e+10    15  Clerical  35100.0
# ..          ...    ...     ...           ...   ...       ...      ...
# 455         455  456.0    Male  1.189719e+10    19   Manager  75000.0
# 457         457  458.0    Male  1.207768e+10    19   Manager  61875.0
# 463         463  464.0    Male  1.197366e+10    19   Manager  47550.0
# 467         467  468.0  Female  1.209021e+10    16   Manager  55750.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
#
#      salbegin  jobtime prevexp minority
# 0     27000.0     98.0   144.0       No
# 1     18750.0     98.0    36.0       No
# 4     21000.0     98.0   138.0       No
# 6     18750.0     98.0   114.0       No
# 13    16800.0     98.0   137.0      Yes
# ..        ...      ...     ...      ...
# 455   42510.0     65.0    54.0       No
# 457   28740.0     65.0    26.0       No
# 463   33000.0     64.0    27.0       No
# 467   19980.0     64.0    36.0       No
# 471   15750.0     63.0    46.0       No
#
# [145 rows x 11 columns]

# %%
sorted=df.sort_values("salary",ascending=False)#high to low
sorted
# more detail in cheat_sheet
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat    salary  \
# 28           28   29.0    Male  1.140117e+10    19   Manager  135000.0
# 31           31   32.0    Male  1.171679e+10    19   Manager  110625.0
# 17           17   18.0    Male  1.178436e+10    16   Manager  103750.0
# 342         342  343.0    Male  1.169666e+10    16   Manager  103500.0
# 445         445  446.0    Male  1.185918e+10    16   Manager  100000.0
# ..          ...    ...     ...           ...   ...       ...       ...
# 89           89   90.0  Female  1.121446e+10     8  Clerical   16200.0
# 223         223  224.0  Female  1.111121e+10    12  Clerical   16200.0
# 410         410  411.0  Female  1.100866e+10    12  Clerical   16200.0
# 337         337  338.0  Female  1.122880e+10     8  Clerical   15900.0
# 377         377  378.0  Female  1.097980e+10     8  Clerical   15750.0
#
#      salbegin  jobtime  prevexp minority
# 28    79980.0     96.0    199.0       No
# 31    45000.0     96.0    120.0       No
# 17    27510.0     97.0     70.0       No
# 342   60000.0     73.0    150.0       No
# 445   44100.0     66.0    128.0      Yes
# ..        ...      ...      ...      ...
# 89     9750.0     92.0  missing       No
# 223   10200.0     82.0  missing       No
# 410   10200.0     68.0    180.0       No
# 337   10200.0     74.0     43.0       No
# 377   10200.0     70.0    275.0       No
#
# [474 rows x 11 columns]

# %%
#add a columns named state, value is AR
df['state']="AR"
df
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 0             0    1.0    Male  1.165415e+10    15   Manager  57000.0
# 1             1    2.0    Male  1.185296e+10    16  Clerical  40200.0
# 2             2    3.0  Female  1.094334e+10    12  Clerical  21450.0
# 3             3    4.0  Female  1.150252e+10     8  Clerical  21900.0
# 4             4    5.0    Male  1.174936e+10    15  Clerical  45000.0
# ..          ...    ...     ...           ...   ...       ...      ...
# 469         469  470.0    Male  1.203180e+10    12  Clerical  26250.0
# 470         470  471.0    Male  1.211164e+10    15  Clerical  26400.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
# 472         472  473.0  Female  1.120634e+10    12  Clerical  21450.0
# 473         473  474.0  Female  1.218292e+10    12  Clerical  29400.0
#
#      salbegin  jobtime prevexp minority state
# 0     27000.0     98.0   144.0       No    AR
# 1     18750.0     98.0    36.0       No    AR
# 2     12000.0     98.0   381.0       No    AR
# 3     13200.0     98.0   190.0       No    AR
# 4     21000.0     98.0   138.0       No    AR
# ..        ...      ...     ...      ...   ...
# 469   15750.0     64.0    69.0      Yes    AR
# 470   15750.0     64.0    32.0      Yes    AR
# 471   15750.0     63.0    46.0       No    AR
# 472   12750.0     63.0   139.0       No    AR
# 473   14250.0     63.0     9.0       No    AR
#
# [474 rows x 12 columns]

# %%
#drop columns
df=df.drop(columns='state')
df
# Out:
#      Unnamed: 0     id  gender         bdate  educ    jobcat   salary  \
# 0             0    1.0    Male  1.165415e+10    15   Manager  57000.0
# 1             1    2.0    Male  1.185296e+10    16  Clerical  40200.0
# 2             2    3.0  Female  1.094334e+10    12  Clerical  21450.0
# 3             3    4.0  Female  1.150252e+10     8  Clerical  21900.0
# 4             4    5.0    Male  1.174936e+10    15  Clerical  45000.0
# ..          ...    ...     ...           ...   ...       ...      ...
# 469         469  470.0    Male  1.203180e+10    12  Clerical  26250.0
# 470         470  471.0    Male  1.211164e+10    15  Clerical  26400.0
# 471         471  472.0    Male  1.209756e+10    15  Clerical  39150.0
# 472         472  473.0  Female  1.120634e+10    12  Clerical  21450.0
# 473         473  474.0  Female  1.218292e+10    12  Clerical  29400.0
#
#      salbegin  jobtime prevexp minority
# 0     27000.0     98.0   144.0       No
# 1     18750.0     98.0    36.0       No
# 2     12000.0     98.0   381.0       No
# 3     13200.0     98.0   190.0       No
# 4     21000.0     98.0   138.0       No
# ..        ...      ...     ...      ...
# 469   15750.0     64.0    69.0      Yes
# 470   15750.0     64.0    32.0      Yes
# 471   15750.0     63.0    46.0       No
# 472   12750.0     63.0   139.0       No
# 473   14250.0     63.0     9.0       No
#
# [474 rows x 11 columns]

# %% [markdown]
# ## plot

# %% [markdown]
# matplotlib: https://matplotlib.org/

# %%
import matplotlib.pyplot as plt

plt.hist(df['gender'],bins=4,color='green')#histogram plot
plt.title('Gender count')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
plt.hist(df['salary'],color='g')#density 
plt.title('Salary distribution')
plt.xlabel('Salary')
plt.ylabel('distribution')

plt.show()

# %% [markdown]
# **different between 2 plot?**

# %% [markdown]
# ## more density plots
# https://seaborn.pydata.org/index.html
#
# install # pip install seaborn

# %%
#pip install seaborn

# %%
import seaborn as sns

#https://seaborn.pydata.org/generated/seaborn.distplot.html

sns.distplot(x=df['salary'], rug=True, hist=True,color='r')
# rug:Whether to draw a rugplot on the support axis.
#hist: Whether to plot a (normed) histogram.
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/distributions.py:2103: FutureWarning:
#
# The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.

# %%
#density for 2 variables
#https://seaborn.pydata.org/generated/seaborn.jointplot.html
sns.jointplot(x=df['salary'],y=df['educ'], kind='hex')

# hex:hexagonal bins

# %%
fig1=sns.jointplot(x=df['salary'],y=df['educ'],kind='kde',hue=df['gender'])

# %%
#salary,educ,gender

fig2=sns.jointplot(x=df['salary'],y=df['educ'],kind='kde',hue=df['jobcat'])

fig2.savefig('salary & gender & jobcat')

# %% [markdown]
# ## plotly express
#
# install: pip install plotly==5.8.0

# %% [markdown]
# https://plotly.com/python/plotly-express/

# %%
#density for 2 variables
import plotly.express as px
plt.figure(figsize=(10, 6))
fig3=px.density_heatmap(df,x='salary',y='educ')
fig3
# Out:
# <div>                            <div id="f27ddfb9-2686-402b-a4ec-caab1ec8ab1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f27ddfb9-2686-402b-a4ec-caab1ec8ab1a")) {                    Plotly.newPlot(                        "f27ddfb9-2686-402b-a4ec-caab1ec8ab1a",                        [{"coloraxis":"coloraxis","hovertemplate":"salary=%{x}<br>educ=%{y}<br>count=%{z}<extra></extra>","name":"","x":[57000.0,40200.0,21450.0,21900.0,45000.0,32100.0,36000.0,21900.0,27900.0,24000.0,30300.0,28350.0,27750.0,35100.0,27300.0,40800.0,46000.0,103750.0,42300.0,26250.0,38850.0,21750.0,24000.0,16950.0,21150.0,31050.0,60375.0,32550.0,135000.0,31200.0,36150.0,110625.0,42000.0,92000.0,81250.0,31350.0,29100.0,31350.0,36000.0,19200.0,23550.0,35100.0,23250.0,29250.0,30750.0,22350.0,30000.0,30750.0,34800.0,60000.0,35550.0,45150.0,73750.0,25050.0,27000.0,26850.0,33900.0,26400.0,28050.0,30900.0,22500.0,48000.0,55000.0,53125.0,21900.0,78125.0,46000.0,45250.0,56550.0,41100.0,82500.0,54000.0,26400.0,33900.0,24150.0,29250.0,27600.0,22950.0,34800.0,51000.0,24300.0,24750.0,22950.0,25050.0,25950.0,31650.0,24150.0,72500.0,68750.0,16200.0,20100.0,24000.0,25950.0,24600.0,28500.0,30750.0,40200.0,30000.0,22050.0,78250.0,60625.0,39900.0,97000.0,27450.0,31650.0,91250.0,25200.0,21000.0,30450.0,28350.0,30750.0,30750.0,54875.0,37800.0,33450.0,30300.0,31500.0,31650.0,25200.0,37800.0,18750.0,32550.0,33300.0,38550.0,27450.0,24300.0,30750.0,19650.0